# %% [raw]
# Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.
#
# Ans:In object-oriented programming (OOP), a class and an object are fundamental concepts that help organize and model real-world entities and their behaviors in software. Let's explain these concepts with an example:
#
# **Class:**
# - A class is a blueprint or a template for creating objects. It defines the properties (attributes) and behaviors (methods) that objects of the class will have.
# - It acts as a prototype for objects, specifying the structure and behavior they should exhibit.
# - Class names are typically written in CamelCase for clarity and convention.
#
# **Object:**
# - An object is an instance of a class. It is a concrete representation of the class, with its own unique data and state.
# - Objects are created based on the class definition, and they can interact with each other and the program.
#
# Example:
#
# Let's consider a simple example of a `Person` class:
#
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def greet(self):
#         print(f"Hello, my name is {self.name} and I am {self.age} years old.")
#
# # Creating objects (instances) of the Person class
# person1 = Person("Alice", 30)
# person2 = Person("Bob", 25)
#
# # Accessing object attributes
# print(person1.name)  # Output: "Alice"
# print(person2.age)   # Output: 25
#
# # Calling object methods
# person1.greet()  # Output: "Hello, my name is Alice and I am 30 years old."
# person2.greet()  # Output: "Hello, my name is Bob and I am 25 years old."
# ```
#
# In this example:
# - `Person` is a class that defines the structure of a person, with attributes `name` and `age` and a method `greet()`.
# - `person1` and `person2` are objects (instances) of the `Person` class, each with its own data.
# - We can access the attributes and methods of each object, and each object behaves independently.
#
# Classes and objects are fundamental to OOP because they allow you to model and represent complex systems, break them down into manageable components, and create reusable code. This approach promotes code organization, modularity, and the ability to model real-world concepts in your programs.

# %% [raw]
# Q2. Name the four pillars of OOPs.
# Ans:-
#  Encapsulation: Encapsulation is the concept of bundling data (attributes) and the methods (functions) that operate on that data into a single unit called a class. It restricts access to certain parts of the object and prevents the direct modification of internal state. Encapsulation helps in data hiding and abstraction, promoting data integrity and security.
#
# Inheritance: Inheritance allows a new class (the subclass or derived class) to inherit properties and behaviors from an existing class (the superclass or base class). It enables code reuse and the creation of a hierarchy of classes, where subclasses inherit and extend the functionality of their parent classes. Inheritance fosters the "is-a" relationship.
#
# Polymorphism: Polymorphism allows objects of different classes to be treated as objects of a common base class. It enables one interface to be used for a general class of actions, making it possible to write more generic and reusable code. Polymorphism can be achieved through method overriding and interfaces in some programming languages.
#
# Abstraction: Abstraction is the process of simplifying complex reality by modeling classes based on their essential properties and behaviors while ignoring non-essential details. It provides a high-level view of an object or system and focuses on what an object does rather than how it does it. Abstraction allows developers to work with simplified, understandable models of objects

# %% [raw]
# Q3. Explain why the __init__() function is used. Give a suitable example.
# Ans:-The __init__() function, also known as the constructor method, is a special method in Python classes. It is automatically called when an object of the class is created. The primary purpose of the __init__() function is to initialize the attributes (properties) of the object with initial values. This allows you to set the object's initial state when it is created.
#
# Here's an example to illustrate the use of the __init__() function:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def introduce(self):
        print(f"My name is {self.name} and I am {self.age} years old.")

# Creating objects and initializing them using the constructor
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)

# Accessing object attributes and methods
person1.introduce()  # Output: "My name is Alice and I am 30 years old."
person2.introduce()  # Output: "My name is Bob and I am 25 years old."
# Out:
# My name is Alice and I am 30 years old.
# My name is Bob and I am 25 years old.

# %% [raw]
# Q4. Why self is used in OOPs?
# Ans:-
#     In object-oriented programming (OOP), self is a convention used to refer to the instance of the class within the class itself. It is a reference to the current object, allowing you to access and manipulate the object's attributes and methods from within its own methods. The use of self is essential for maintaining the object's state and behavior and for distinguishing instance variables and methods from local variables.
#
# Here are a few key reasons why self is used in OOP:
#
# Accessing Object Attributes: When you create an object from a class, self is used to access and modify the object's attributes (instance variables). For example, self.name refers to the name attribute of the current object.
#
# Calling Object Methods: Inside a class, you use self to call other methods of the same object. This allows methods to interact with and modify the object's state and behavior. For example, self.method_name() calls another method of the object.
#
# Distinguishing Between Local and Instance Variables: When a method has local variables with the same name as instance variables, using self helps clarify that you are working with instance variables. For example, if there's a local variable name and an instance variable self.name, self.name explicitly refers to the object's attribute.
#
# Avoiding Confusion: In a class, you may have multiple objects created from the same class blueprint. Using self ensures that each object refers to its own attributes and methods, avoiding confusion between objects.

# %% [raw]
# Q5. What is inheritance? Give an example for each type of inheritance.
# Ans:-
#     Inheritance is one of the fundamental concepts of object-oriented programming (OOP) that allows a new class (the subclass or derived class) to inherit properties and behaviors from an existing class (the superclass or base class). It promotes code reuse and the creation of a hierarchy of classes, where subclasses inherit and extend the functionality of their parent classes.
#
# There are several types of inheritance in OOP, including:
#
# 1. **Single Inheritance**: In single inheritance, a subclass inherits from a single superclass.
#
#    Example:
#    ```python
#    class Animal:
#        def speak(self):
#            pass
#
#    class Dog(Animal):
#        def speak(self):
#            return "Woof!"
#
#    dog = Dog()
#    print(dog.speak())  # Output: "Woof!"
#    ```
#
# 2. **Multiple Inheritance**: In multiple inheritance, a subclass inherits from multiple superclasses. Python supports multiple inheritance.
#
#    Example:
#    ```python
#    class A:
#        def method_a(self):
#            return "Method A"
#
#    class B:
#        def method_b(self):
#            return "Method B"
#
#    class C(A, B):
#        pass
#
#    c = C()
#    print(c.method_a())  # Output: "Method A"
#    print(c.method_b())  # Output: "Method B"
#    ```
#
# 3. **Multilevel Inheritance**: In multilevel inheritance, a subclass inherits from a superclass, and then another subclass inherits from the first subclass. This creates a chain of inheritance.
#
#    Example:
#    ```python
#    class Grandparent:
#        def speak(self):
#            return "Hello from Grandparent!"
#
#    class Parent(Grandparent):
#        pass
#
#    class Child(Parent):
#        pass
#
#    child = Child()
#    print(child.speak())  # Output: "Hello from Grandparent!"
#    ```
#
# 4. **Hierarchical Inheritance**: In hierarchical inheritance, multiple subclasses inherit from a single superclass.
#
#    Example:
#    ```python
#    class Shape:
#        def area(self):
#            pass
#
#    class Circle(Shape):
#        def area(self):
#            return 3.14 * self.radius ** 2
#
#    class Rectangle(Shape):
#        def area(self):
#            return self.length * self.width
#
#    circle = Circle()
#    circle.radius = 5
#    print(circle.area())  # Output: 78.5
#
#    rectangle = Rectangle()
#    rectangle.length = 4
#    rectangle.width = 6
#    print(rectangle.area())  # Output: 24
#    ```
#
# 5. **Hybrid Inheritance**: Hybrid inheritance is a combination of different types of inheritance. It can involve multiple, multilevel, or hierarchical inheritance in a single class hierarchy.
#
#    Example:
#    ```python
#    class A:
#        def method_a(self):
#            return "Method A"
#
#    class B(A):
#        def method_b(self):
#            return "Method B"
#
#    class C(B):
#        pass
#
#    class D(A):
#        def method_d(self):
#            return "Method D"
#
#    class E(C, D):
#        pass
#
#    e = E()
#    print(e.method_a())  # Output: "Method A"
#    print(e.method_b())  # Output: "Method B"
#    print(e.method_d())  # Output: "Method D"
#    ```
#
# These examples demonstrate various types of inheritance in Python, illustrating how classes can inherit and extend the properties and behaviors of other classes. Inheritance is a powerful mechanism that promotes code reuse and allows for the creation of complex class hierarchies.
